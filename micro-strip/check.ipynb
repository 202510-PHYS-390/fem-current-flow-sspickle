# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output_files/port_it_1", skiprows=4, header=None, names=['t','i'], sep='\s+')
df.head()
# Out:
#               t         i
# 0  1.614844e-14  0.000000
# 1  4.957572e-12  0.000020
# 2  9.898996e-12  0.000031
# 3  1.484042e-11  0.000038
# 4  1.978184e-11  0.000046

# %%
plt.plot(df['t'], df['i'])
plt.grid()

# %%
dfv = pd.read_csv("output_files/port_ut_1", skiprows=4, header=None, names=['t','v'], sep='\s+')
dfv.head()
# Out:
#               t         v
# 0  0.000000e+00 -0.000000
# 1  4.941424e-12  0.001200
# 2  9.882848e-12  0.001461
# 3  1.482427e-11  0.001703
# 4  1.976570e-11  0.001977

# %%
plt.plot(dfv['t'], dfv['v'])
plt.grid()

# %%
dfv['t'].values[83]
# Out:
# 4.10138172791e-10
